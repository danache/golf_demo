# %%
import os
import os.path as osp
import numpy as np
import argparse

import cv2
import sys
import time
import sys

import tensorflow as tf

import matplotlib.pyplot as plt
# Out:
# /home/bnrc2/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %cd ..
# Out:
# /home/bnrc2/mu/golf_demo

# %%
from src.skeleton.CPN.Cpn_datagen import DataGenerator

# %%
valid_data = DataGenerator(json="/media/bnrc2/_backup/dataset/output/golf.json",
                                   img_path="/media/bnrc2/_backup/dataset/normalsizeImages/png")

# %%
generator = valid_data.get_batch_generator()

# %%
gt_img, img, details ,name= next(generator)

img_ori = img.transpose(1,2,0)* 255 / 2 + np.array([[[102.9801, 115.9465, 122.7717]]])         

plt.imshow(img_ori.astype(np.uint8))

# %%
1.找到人的中心（
